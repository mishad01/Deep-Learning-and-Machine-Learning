# %% [markdown]
# <a href="https://colab.research.google.com/github/mishad01/Data-Science-Machine-Learning/blob/main/8_handling_missing_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Handling Missing Data
# Missing data is very common in many data analysis applications. pandas has a great ability to deal with the missing data. <br>Let's learn some convenient methods to deal with **missing data in pandas**:<br>
#
# * isnull(), isna(), notnull(), dropna(), fillna(),

# %%
import numpy as np
import pandas as pd

# %%
data_dic = {'A':[1,2,None,4,np.nan],
            'B':[np.nan,np.nan,np.nan,np.nan,np.nan],
            'C':[11,12,13,14,15],
            'D':[16,np.nan,18,19,20]}

# %%
df = pd.DataFrame(data_dic)
df
# Out:
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12   NaN
# 2  NaN NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  NaN NaN  15  20.0

# %% [markdown]
# **isnull(), isna(), notnull() -- Check for missing data in the dataset!**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      float64
#  1   B       0 non-null      float64
#  2   C       5 non-null      int64
#  3   D       4 non-null      float64
# dtypes: float64(3), int64(1)
# memory usage: 288.0 bytes

# %%
df.isnull()
# Out:
#        A     B      C      D
# 0  False  True  False  False
# 1  False  True  False   True
# 2   True  True  False  False
# 3  False  True  False  False
# 4   True  True  False  False

# %%
df.isnull().sum() #return how many null presents in column
# Out:
# A    2
# B    5
# C    0
# D    1
# dtype: int64

# %%
df.isnull().sum().sum() #to see the total sum we use double sum
# Out:
# 8

# %%
df['A'].isnull() #returns null in A series
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# Name: A, dtype: bool

# %%
df['A'].isnull().sum()
# Out:
# 2

# %%
df.isna() #isull() and isna() same stuff
# Out:
#        A     B      C      D
# 0  False  True  False  False
# 1  False  True  False   True
# 2   True  True  False  False
# 3  False  True  False  False
# 4   True  True  False  False

# %%
df.isna().sum().sum()
# Out:
# 8

# %%
df.loc[1].isnull().sum() #1 means, how many null present in row 1
# Out:
# 2

# %%
df.notnull()
# Out:
#        A      B     C      D
# 0   True  False  True   True
# 1   True  False  True  False
# 2  False  False  True   True
# 3   True  False  True   True
# 4  False  False  True   True

# %%
df.shape #it will return(row,col)
# Out:
# (5, 4)

# %%
df.notnull().sum()
# Out:
# A    3
# B    0
# C    5
# D    4
# dtype: int64

# %%
df.notna().sum()
# Out:
# A    3
# B    0
# C    5
# D    4
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 12

# %%
df
# Out:
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12   NaN
# 2  NaN NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  NaN NaN  15  20.0

# %%
# Sum on Column "A", (NaN as 0)
df['A'].sum()
# Out:
# 7.0

# %% [markdown]
# &#9758; NaN ignored for mean().

# %%
df['A'].mean() #  Average
# Out:
# 2.3333333333333335

# %%
df.loc[3].mean() #Row wise Average
# Out:
# 12.333333333333334

# %% [markdown]
# **dropna(), fillna() -- Cleaning / filling the missing data**<br>
#
# *   When We want to drop row with null value we use dropna()
# *   List item

# %%
df
# Out:
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12   NaN
# 2  NaN NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  NaN NaN  15  20.0

# %%
df.dropna(axis=0) #When We want to drop row with null value we use dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df
# Out:
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12   NaN
# 2  NaN NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  NaN NaN  15  20.0

# %%
df.dropna(axis=1) #When We want to drop row with null value we use dropna()
# Out:
#     C
# 0  11
# 1  12
# 2  13
# 3  14
# 4  15

# %%
df
# Out:
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12   NaN
# 2  NaN NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  NaN NaN  15  20.0

# %% [markdown]
# Not null value is thrrsh
# thresh : int, default None<br>
# thresh = 3 means, it will drop any column that have less than 3 non-NaN values.<br>

# %%
df.dropna(axis=1,thresh=5) #if there is not 5 value in column, it will drop
# Out:
#     C
# 0  11
# 1  12
# 2  13
# 3  14
# 4  15

# %%
df.dropna(axis=1,thresh=3)
# Out:
#      A   C     D
# 0  1.0  11  16.0
# 1  2.0  12   NaN
# 2  NaN  13  18.0
# 3  4.0  14  19.0
# 4  NaN  15  20.0

# %% [markdown]
# We can use fillna() to fill in the values.<br>
# inplaced = True for permanent change.

# %%
df.fillna(value=2) #Replace null value with 2
# Out:
#      A    B   C     D
# 0  1.0  2.0  11  16.0
# 1  2.0  2.0  12   2.0
# 2  2.0  2.0  13  18.0
# 3  4.0  2.0  14  19.0
# 4  2.0  2.0  15  20.0

# %%
df
# Out:
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12   NaN
# 2  NaN NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  NaN NaN  15  20.0

# %%
df['A'].fillna(value=df['A'].mean()) #Replacing value with Fillna
# Out:
# 0    1.000000
# 1    2.000000
# 2    2.333333
# 3    4.000000
# 4    2.333333
# Name: A, dtype: float64

# %% [markdown]
# #method(ffill) -> Null value will replaced with its previous/upper value<br>
# #df.fillna(method='bfill')-> Null value will replaced with its next/lower value

# %%
df
# Out:
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12   NaN
# 2  NaN NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  NaN NaN  15  20.0

# %%
df.fillna(method='ffill') #method(ffill) -> Null value will replaced with its previous value
# Out:
# <ipython-input-21-ed2ae406e7a1>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill') #method(ffill) -> Null value will replaced with its previous value
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12  16.0
# 2  2.0 NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  4.0 NaN  15  20.0

# %%
df
# Out:
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12   NaN
# 2  NaN NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  NaN NaN  15  20.0

# %%
df.fillna(method='bfill') #df.fillna(method='bfill')-> Null value will replaced with its next/lower value
# Out:
# <ipython-input-18-3f8c85658ac8>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='bfill') #df.fillna(method='bfill')-> Null value will replaced with its next/lower value
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12  18.0
# 2  4.0 NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  NaN NaN  15  20.0

# %% [markdown]
# #The SimpleImputer class in scikit-learn is used to handle missing data by replacing missing values with a specified constant or a statistical measure (mean, median, or most frequent value) computed from the dataset. It's a simple and efficient way to impute missing values.

# %%
from sklearn.impute import SimpleImputer

# %%
df2 = df.copy()
df2
# Out:
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12   NaN
# 2  NaN NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  NaN NaN  15  20.0

# %%
imputer = SimpleImputer(strategy='constant',fill_value=-1)
df2['A'] = imputer.fit_transform(df2[['A']]) #Here all the null value of A column will be filled with -1
df2
# Out:
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12   NaN
# 2 -1.0 NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4 -1.0 NaN  15  20.0

# %%
df2 = df.copy()
imputer = SimpleImputer(strategy='constant',fill_value=-1)
df2['B'] = imputer.fit_transform(df2[['B']]) #Here all the null value of B column will be filled with -1
df2
# Out:
#      A    B   C     D
# 0  1.0 -1.0  11  16.0
# 1  2.0 -1.0  12   NaN
# 2  NaN -1.0  13  18.0
# 3  4.0 -1.0  14  19.0
# 4  NaN -1.0  15  20.0

# %%
df2 = df.copy()
imputer = SimpleImputer(strategy='mean')
df2['A'] = imputer.fit_transform(df2[['A']]) #Here all the null value of B column will be filled with -1
df2
# Out:
#           A   B   C     D
# 0  1.000000 NaN  11  16.0
# 1  2.000000 NaN  12   NaN
# 2  2.333333 NaN  13  18.0
# 3  4.000000 NaN  14  19.0
# 4  2.333333 NaN  15  20.0

# %%
df2 = df.copy()
imputer = SimpleImputer(strategy='mean')
df2= imputer.fit_transform(df2) #Here all the null value will be filled with mean
df2
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:598: UserWarning: Skipping features without any observed values: ['B']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# array([[ 1.        , 11.        , 16.        ],
#        [ 2.        , 12.        , 18.25      ],
#        [ 2.33333333, 13.        , 18.        ],
#        [ 4.        , 14.        , 19.        ],
#        [ 2.33333333, 15.        , 20.        ]])

# %%
df2 = df.copy()
imputer = SimpleImputer(strategy='median')
df2['A'] = imputer.fit_transform(df2[['A']]) #Here all the null value of B column will be filled with -1
df2
# Out:
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12   NaN
# 2  2.0 NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  2.0 NaN  15  20.0

# %%
df2 = df.copy()
imputer = SimpleImputer(strategy='most_frequent')
df2['D'] = imputer.fit_transform(df2[['D']]) #Here all the null value of B column will be filled with -1
df2
# Out:
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12  16.0
# 2  NaN NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  NaN NaN  15  20.0

# %% [markdown]
# #The KNNImputer class in scikit-learn is used to handle missing values in a dataset by imputing them using the k-nearest neighbors algorithm. This imputation method fills in missing values based on the values of the nearest neighbors of the data point with missing values.

# %%
from sklearn.impute import KNNImputer

# %%
df2 = df.copy()
df2
# Out:
#      A   B   C     D
# 0  1.0 NaN  11  16.0
# 1  2.0 NaN  12   NaN
# 2  NaN NaN  13  18.0
# 3  4.0 NaN  14  19.0
# 4  NaN NaN  15  20.0

# %%
knn_imputer= KNNImputer(n_neighbors=2,weights='uniform') #gives average from neighbors
A1 = knn_imputer.fit_transform(df2)
A1
# Out:
# array([[ 1., 11., 16.],
#        [ 2., 12., 17.],
#        [ 3., 13., 18.],
#        [ 4., 14., 19.],
#        [ 3., 15., 20.]])

# %%
df2 = pd.DataFrame(A1,columns=['A','C','D'])
df2
# Out:
#      A     C     D
# 0  1.0  11.0  16.0
# 1  2.0  12.0  17.0
# 2  3.0  13.0  18.0
# 3  4.0  14.0  19.0
# 4  3.0  15.0  20.0

# %%
# fill with you own given value
df.fillna(0, inplace=True)
df
# Out:
#      A    B   C     D
# 0  1.0  0.0  11  16.0
# 1  2.0  0.0  12   0.0
# 2  0.0  0.0  13  18.0
# 3  4.0  0.0  14  19.0
# 4  0.0  0.0  15  20.0
