# %% [markdown]
# <a href="https://colab.research.google.com/github/mishad01/Data-Science-Machine-Learning/blob/main/8_Data_Visualization_using_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Built-in Data Visualization
#
# Hi Guys,<br>
# Welcome to [pandas for Data Visualization](https://pandas.pydata.org/pandas-docs/stable/visualization.html) now. In the Data Analysis section, we have explored the power of pandas for data analysis. Let's talk about pandas built-in data visualization capabilities. We can create decent looking plots using pandas. This is actually built on matplotlib and embedded into pandas for quick use. <br>
#
# Let's take a look!
# ### Histograms
# ### Area plot
# ### Bar plots
# ### Line plots
# ### Scatter plots
# ### BoxPlots
# ### Pie Plot

# %% [markdown]
# Let's create some random datasets now! <br>
# df1 with date as index and df2 with sequential index.
#
# *Although, we can use seaborn built-in datasets as well. To make this lecture as a separate and independent, I am creating new data frames here to use.*

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# Let's use numpy's randn for "standard normal" distribution
data1 = np.random.randn(500,3) #(500,3) to tell the shape we want
data1
# Out:
# array([[ 1.38236347,  0.1950209 ,  1.5883001 ],
#        [-0.80737708, -1.44960488, -0.82154563],
#        [ 0.20655965, -1.03683018, -2.07940741],
#        ...,
#        [ 0.39821062, -1.71159987,  1.65134071],
#        [-0.18840468, -0.7514868 ,  1.92349253],
#        [ 1.44298306,  0.04011773,  0.87481244]])

# %%
data1.shape #.shape returns how many row and columns are present here
# Out:
# (500, 3)

# %%
df1 = pd.DataFrame(data = data1, columns=['A', 'B', 'C'])

# %%
df1['D'] = np.random.rand(500)
df1
# Out:
#             A         B         C         D
# 0    1.382363  0.195021  1.588300  0.972791
# 1   -0.807377 -1.449605 -0.821546  0.110626
# 2    0.206560 -1.036830 -2.079407  0.471579
# 3    0.077673  0.646398 -0.727713  0.890844
# 4    1.863989 -0.452466 -1.595726  0.812551
# ..        ...       ...       ...       ...
# 495 -1.531666 -0.518650  0.251014  0.834566
# 496  1.265319  0.409593  0.260827  0.228206
# 497  0.398211 -1.711600  1.651341  0.555065
# 498 -0.188405 -0.751487  1.923493  0.473545
# 499  1.442983  0.040118  0.874812  0.229918
#
# [500 rows x 4 columns]

# %% [markdown]
# ### Generating `df2`

# %%
# rand(20,3) 20 by 3 2D array
data2 = np.random.rand(20,3)
col = ['X', 'Y', 'Z']
df2 = pd.DataFrame(data = data2, columns=col)

# %% [markdown]
# Let's start with simple histogram plot, we can get the hist plot in two ways!
# * `DataFrame.hist()`
# * `DataFrame.plot(kind = 'hist')`
#
# Let's try both one-by-one first, later on, we will talk about style sheet and discuss the range of plotting options in details!
#
# ***
# #df.hist()
# - DataFrame.hist(): Creates a histogram for each column in the DataFrame using Matplotlib.-
# - Automatically generates subplots for multiple columns.
#
# #df.plot(kind='hist')
#  - DataFrame.plot(kind='hist'): Uses Pandas' built-in plotting, also based on Matplotlib,
#  - to create a histogram. Allows more customization options but doesn't create subplots automatically for multiple columns.
#
# ***

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(edgecolor = 'black')
# Out:
# <Axes: >

# %% [markdown]
# - x-axis = bins
# - y -axis = frequency

# %%
df1['A'].hist(edgecolor = 'black',bins=30)
# Out:
# <Axes: >

# %% [markdown]
# # we can also plot using kind

# %%
df1['A'].plot(kind='hist',bins = 20,edgecolor ='black',figsize=(12,5))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #For whole dataset

# %%
df1.plot(kind='hist',bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Style Sheets
#
# Matplotlib has [style sheets](http://matplotlib.org/gallery.html#style_sheets). We can use this to make our plots look a little nicer. These style sheets include `plot_bmh`,`plot_fivethirtyeight`,`plot_ggplot` and more. They basically create a set of style rules that our plots follow. Its good to use them because they make all our plots to have the same look and feel more professional. <br>
# Let's call the style first!

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')  # Applying ggplot style

# %%
df1['A'].hist(bins=30)
# Out:
# <Axes: >

# %%
plt.style.use('bmh') #bmh style
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
# we can use dark_background
plt.style.use('dark_background')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
# another example
plt.style.use('fivethirtyeight')
df1['A'].hist(bins=50)
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
df2['X'].plot(kind='hist', bins=20) #its not normal histogram
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Plot Types
#
# There are several plot types built-in to pandas, most of them are statistical plots by nature:
#
# * `df.plot.area`
# * `df.plot.bar`
# * `df.plot.barh`
# * `df.plot.hist`
# * `df.plot.line`
# * `df.plot.scatter`
# * `df.plot.box`
# * `df.plot.pie`
#
# We can also just call `df.plot(kind='hist')` or replace that kind argument with any of the key terms shown in the list above (e.g. `'box','barh'`, etc..)<br>
# **Let's go through these plots one-by-one using our data frames `df1` and `df2`!**

# %%
df2
# Out:
#            X         Y         Z
# 0  -0.400658 -0.812664  0.204297
# 1   0.704814  0.763468  0.809904
# 2   0.519654  0.006555  0.293935
# 3   0.456674  1.106799 -0.611435
# 4  -0.912424 -0.653762  1.520762
# 5  -1.729448  0.686585  0.103935
# 6  -1.027671 -0.669014 -0.714365
# 7   0.055389 -0.340046  0.239662
# 8  -0.964231 -0.130458  1.346958
# 9  -0.709978 -0.533537 -0.964222
# 10 -2.259097  0.094896 -0.192066
# 11 -0.948055  0.302625 -0.451087
# 12  0.455078  0.308528  0.180401
# 13 -0.051309 -0.996941  0.316801
# 14  1.280962  0.745213  1.387175
# 15  0.496136  0.328650 -0.257899
# 16  0.082057  0.143919  0.725967
# 17  0.640708  1.222268 -0.467987
# 18 -0.808253 -0.408457 -0.618931
# 19  0.924224  0.829823 -0.629774

# %%
df2['X'].plot()
# Out:
# <Axes: >

# %%
plt.style.use('ggplot')

df2.plot.scatter(x='X',y='Y',figsize=(12,3))
# Out:
# <Axes: xlabel='X', ylabel='Y'>

# %%
df2.plot(stacked=True)

# %%
df2.plot.line(x='X', y='Y',figsize=(12,3))
# Out:
# <Axes: xlabel='X'>

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2
# Out:
#            X         Y         Z
# 0  -0.400658 -0.812664  0.204297
# 1   0.704814  0.763468  0.809904
# 2   0.519654  0.006555  0.293935
# 3   0.456674  1.106799 -0.611435
# 4  -0.912424 -0.653762  1.520762
# 5  -1.729448  0.686585  0.103935
# 6  -1.027671 -0.669014 -0.714365
# 7   0.055389 -0.340046  0.239662
# 8  -0.964231 -0.130458  1.346958
# 9  -0.709978 -0.533537 -0.964222
# 10 -2.259097  0.094896 -0.192066
# 11 -0.948055  0.302625 -0.451087
# 12  0.455078  0.308528  0.180401
# 13 -0.051309 -0.996941  0.316801
# 14  1.280962  0.745213  1.387175
# 15  0.496136  0.328650 -0.257899
# 16  0.082057  0.143919  0.725967
# 17  0.640708  1.222268 -0.467987
# 18 -0.808253 -0.408457 -0.618931
# 19  0.924224  0.829823 -0.629774

# %%
df2.plot(stacked=True)
# Out:
# <Axes: >

# %%
df2['X'].plot(kind='area')
# Out:
# <Axes: >

# %%
df2['X'].plot.area()
# Out:
# <Axes: >

# %%
df2.plot.area()
# Out:
# <Axes: >

# %%
df2.plot.area(stacked=False)
# Out:
# <Axes: >

# %% [markdown]
# ### Bar plots

# %%
df2['X'].plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %%
df2.plot.bar(figsize=(15,5))
# Out:
# <Axes: >

# %% [markdown]
# # Horizontal bars
# - barh ( h= horizontal )

# %%
df2.plot.barh(figsize=(15,5))
# Out:
# <Axes: >

# %% [markdown]
# #plt.style.use('ggplot')
# df2.plot.bar(stacked=True, figsize=(10,5))
#
# - With stacked=True:
# The values for "Category A," "Category B," and "Category C" for "X" will appear as one bar, with each section stacked on top of the others.
#
# - Witht stacked=False:
# Each category will have its own separate bar for "X," "Y," and "Z," aligned side by side.

# %%
plt.style.use('ggplot')
df2.plot.bar(stacked=True, figsize=(10,5))
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=False, figsize=(10,5))
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='A', y='B', figsize=(12,3))
#plt.show()
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.line(x='A', y='B',figsize=(12,3),lw=.5,color='green')# lw = line width # Plots a line graph with 'A' as the x-axis, 'B' as the y-axis, specified figure size, and line width.
# Out:
# <Axes: xlabel='A'>

# %% [markdown]
# - df1.plot.scatter(x='A', y='B', c='0.8', cmap='coolwarm', figsize=(12, 3))
# - Creates a scatter plot with 'A' on the x-axis and 'B' on the y-axis.
# - The color intensity is specified by '0.8' with the 'coolwarm' colormap applied.
# - The figure size is set to 12x3 inches.

# %%
df1.plot.scatter(x='A', y='B', c='0.8', cmap='coolwarm', figsize=(12,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A',y='B', c='D', cmap='coolwarm', figsize=(12,3)) #if we want 3 vairable we can do this by giving D value in color
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# We can use 's' to indicate size
df1.plot.scatter(x='A', y='B', s=90,  figsize=(12,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# - df1.plot.scatter(x='A', y='B', s=df1['D']*100, figsize=(12, 3))
# - Creates a scatter plot with 'A' on the x-axis and 'B' on the y-axis.
# - The size of each point is proportional to the values in column 'D', scaled by 100.
# - The figure size is set to 12x3 inches.

# %%
df1.plot.scatter(x='A', y='B', s=df1['D']*100, figsize=(12,3))
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
# We can use 's' to indicate size
df1.plot.scatter(x='A', y='B', s=df1['D']*100, c='D', cmap='coolwarm', figsize=(12,3)) # we are using 4 variable here using s,c where s is size and c is color
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df1.plot.hexbin(x='A',y='B', gridsize=30, cmap='Oranges',  figsize=(12,3)) #we can understand density(ghonotto) using hexbin
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# ### Line plots

# %%
gas = pd.read_csv('/content/drive/MyDrive/ml_data/gas_prices.csv')

# %%
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
gas['UK'].plot()
# Out:
# <Axes: >

# %%
gas.plot(x='Year', y='USA',figsize=(10,5))
# Out:
# <Axes: xlabel='Year'>

# %%
gas.Year[::3].tolist()  # This returns a list of every third element from the 'Year' column of the 'gas' DataFrame.
# Out:
# [1990, 1993, 1996, 1999, 2002, 2005, 2008]

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.style.use('dark_background')

# %%
gas.plot(x='Year', y='UK', xticks=gas.Year[::3].tolist())  # This plots 'UK' values against 'Year' with xticks showing every third year from the 'Year' column.
# Out:
# <Axes: xlabel='Year'>

# %%
gas.plot(x='Year', y='UK', xticks=gas.Year[::3].tolist())  # This plots 'UK' values against 'Year' with xticks showing every third year from the 'Year' column.
gas.plot(x='Year', y='USA', xticks=gas.Year[::3].tolist())  # This plots 'UK' values against 'Year' with xticks showing every third year from the 'Year' column.
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ### Using Pyplot

# %%
plt.style.use('dark_background')

# %%
plt.subplots(figsize=(10,5))
plt.plot(gas['Year'],gas['USA'],label='USA',marker ='o')
plt.plot(gas['Year'],gas['Canada'],label = 'Canada',marker='*')
plt.xticks(gas.Year[::3].tolist());
#plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title('Gas Prices over Time (in USD)',fontdict={'fontweight':'bold', 'fontsize': 18, 'color':'g'})
plt.plot(gas.Year, gas.USA, 'w.-',label ='USA')
plt.plot(gas.Year, gas['Canada'], 'r.-', label='Canada')
plt.plot(gas.Year, gas['South Korea'], 'g.-', label='SKorea')
plt.plot(gas.Year, gas.Australia, 'y.-', label='Austrolia')

plt.xticks(gas.Year[::3].tolist());
plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()
plt.savefig('Gas_price_figure.png', dpi=300, bbox_inches ='tight')

#plt.grid()
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot()


plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18, 'color':'g'})

plt.plot(gas.Year, gas.USA, 'b.-', label='USA')
plt.plot(gas.Year, gas['Canada'], 'r.-', label='Canada')
plt.plot(gas.Year, gas['South Korea'], 'g.-', label='SKorea')
plt.plot(gas.Year, gas.Australia, 'y.-', label='Austrolia')

plt.xticks(gas.Year[::3].tolist()); #[1990, 1993, 1996, 1999, 2002, 2005, 2008]

for i,j in zip(gas.Year,gas['South Korea']):
  if i in gas.Year[::3].tolist():
    ax.annotate('%s' %j, xy=(i,j), xytext=(0,10), textcoords='offset points')

# %%
roll = (101, 102, 103, 104, 105, 106)
name = ("Jenny", "Christy", "Monica", "John", "Charles", "Mike")

result = list(zip(roll, name))
print(result)
# Out:
# [(101, 'Jenny'), (102, 'Christy'), (103, 'Monica'), (104, 'John'), (105, 'Charles'), (106, 'Mike')]

# %% [markdown]
# ## BoxPlots
# To visualize the distribution of values within each column.

# %%
df2
# Out:
#            X         Y         Z
# 0   0.444592  0.159598  0.513654
# 1   0.596703  0.419239  0.131825
# 2   0.450626  0.773599  0.612774
# 3   0.999497  0.009427  0.393545
# 4   0.714212  0.388757  0.064077
# 5   0.303848  0.430271  0.171310
# 6   0.898551  0.834571  0.347076
# 7   0.708364  0.652517  0.898900
# 8   0.785506  0.025637  0.092025
# 9   0.827510  0.130037  0.442903
# 10  0.559912  0.351718  0.965463
# 11  0.076864  0.284351  0.504675
# 12  0.204943  0.623970  0.759410
# 13  0.980811  0.477244  0.469007
# 14  0.453366  0.506028  0.901845
# 15  0.787584  0.594626  0.419344
# 16  0.326038  0.083238  0.729751
# 17  0.530246  0.014545  0.447617
# 18  0.574380  0.772266  0.191078
# 19  0.288554  0.682421  0.464486

# %%
df2['X'].max()
# Out:
# 0.999496651141568

# %%
df2['X'].min()
# Out:
# 0.0768644669892129

# %%
df2['X'].quantile(0.50)
# Out:
# 0.5671457266852772

# %%
df2['X'].plot.box()
# Out:
# <Axes: >

# %%
df2.plot.box()
# Out:
# <Axes: >

# %%
df2.plot.box(vert=False)  # This creates a horizontal box plot for the DataFrame 'df2'.
# Out:
# <Axes: >

# %% [markdown]
# ## Pie Plot
# We can create a pie plot with  `Series.plot.pie()` or `DataFrame.plot.pie()`. If your data includes any NaN, they will be automatically filled with 0. A ValueError will be raised if there are any negative values in your data.<br>
# Let's try pie plot with df2.<br>
#
# We need to specify a target column by the y argument. When y is specified, pie plot of selected column will be drawn.

# %%
df2
# Out:
#            X         Y         Z
# 0   0.550435  0.130570  0.377706
# 1   0.033302  0.194981  0.905463
# 2   0.086980  0.227799  0.947129
# 3   0.322313  0.015498  0.353022
# 4   0.177355  0.628020  0.476754
# 5   0.806503  0.363536  0.922357
# 6   0.349869  0.785303  0.146863
# 7   0.970607  0.297203  0.946139
# 8   0.193704  0.267485  0.453905
# 9   0.737563  0.230686  0.917198
# 10  0.412237  0.682821  0.671037
# 11  0.814875  0.058438  0.762927
# 12  0.390844  0.136474  0.329924
# 13  0.133974  0.069519  0.806565
# 14  0.192939  0.109825  0.048785
# 15  0.222158  0.201868  0.258879
# 16  0.137619  0.491297  0.995392
# 17  0.553623  0.392871  0.003740
# 18  0.043342  0.329603  0.721215
# 19  0.287384  0.723436  0.736954

# %%
df2.plot.pie(
    y='X',                # Specifies the column 'X' from DataFrame df2 to be used for the pie chart.
    figsize=(12, 10),     # Sets the figure size to 12 inches wide and 10 inches tall.
    autopct='%.1f%%'      # Displays percentage values on the pie chart with two decimal places.
)
# Out:
# <Axes: ylabel='X'>

# %%
fifa = pd.read_csv("/content/drive/MyDrive/ml_data/fifa_data.csv")
fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
pd.set_option('display.max_columns', None)
# Sets the pandas display option to show all columns in the DataFrame when displayed.
# 'None' means there is no limit, so all columns will be visible regardless of the number of columns in the DataFrame.

fifa
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
fifa['Weight']
# Out:
# 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 18202    134lbs
# 18203    170lbs
# 18204    148lbs
# 18205    154lbs
# 18206    176lbs
# Name: Weight, Length: 18207, dtype: object

# %%
def stripdata(x):
  if type(x) == str:
    return float(x[0:3])
  else:
    return x

# %%
stripdata('685kg')
# Out:
# 685.0

# %%
fifa['Weight']=fifa['Weight'].apply(stripdata)

# %%
fifa['Weight']
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
#          ...
# 18202    134.0
# 18203    170.0
# 18204    148.0
# 18205    154.0
# 18206    176.0
# Name: Weight, Length: 18207, dtype: float64

# %%
fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
light = fifa[fifa['Weight']<125]

# %%
light = fifa[fifa['Weight']<125].count()

# %%
light = fifa[fifa['Weight']<125].count()[0] #I want just the first one
light
# Out:
# 41

# %%
light = fifa[fifa.Weight < 125].count()[0]
light_medium = fifa[(fifa.Weight >=125) & (fifa.Weight<150)].count()[0]
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa[fifa.Weight >= 200].count()[0]

weights = [light,light_medium, medium, medium_heavy, heavy]
weights
# Out:
# [41, 2290, 10876, 4583, 369]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
label = ['under 125', '125-150', '150-175', '175-200', 'over 200']
explodelist = [.4,.2,0,0,.4]

plt.pie(
    weights,               # The data values to be plotted as slices of the pie chart.
    labels=label,          # The labels corresponding to each slice.
    explode=explodelist,   # A list that determines the fraction to offset each slice from the center (e.g., [0.1, 0, 0] to offset the first slice).
    autopct='%1.1f%%',     # Formats the percentage values displayed on the slices with one decimal place.
    pctdistance=0.8        # Adjusts the distance of the percentage text from the center of the pie.
)

plt.show()
